# %%
# Use scrap_g_search_links_with_check_wp.ipynb instead!

from bs4 import BeautifulSoup
import openpyxl
import requests, re
import pandas as pd
import numpy as np
from urllib.parse import urlsplit
from collections import deque
from datetime import datetime, date

search_for = "dentist" #Change only this string
search_for = search_for.replace(" ", "+")
i = 0
n = 1
links_list = {"Pos #" : [], "Page #" : [], "Website" : []}
headers = {
    "User-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36"
}
cities = ["Seattle"]#, "Los Angeles"]#, "Tampa", "Brooklyn", "Phoenix"]
# cities = ['Roanoke','Nampa ','Edinburg ','Clinton ','Federal Way ','New Bedford ','Lees Summit ','Lynn ','Chico ','Quincy ','Davenport ','Wichita Falls ',
# 'Vacaville ','Menifee ','Norwalk ','Spokane Valley ','South Bend ','Woodbridge ','Rialto ','Rio Rancho ','Allen ','Daly City ','Jurupa Valley','Concord ',
# 'Brockton ','San Mateo ','Davie','Tyler ','El Cajon ','Hillsboro ','Renton ','Burbank ','Green Bay ','South Fulton ','Edison ','Inglewood ','Sandy Springs ',
# 'Boulder ','Centennial ','Sparks ','Greeley ','El Monte ','West Covina ','Santa Maria ','Dearborn ','Temecula ','Everett ','Ventura','Murrieta ','Sugar Land ',
# 'Las Cruces ','Miami Gardens ','Lewisville ','Pueblo ','Costa Mesa ','Pompano Beach ','Lakeland ','Lansing ','Peoria ','Broken Arrow ','High Point ','Gresham ',
# 'Downey ','League City ','Springfield ','Waterbury ','Odessa ','Carlsbad ','Elgin ','North Charleston ','Provo ','Beaumont ','Antioch ','Wilmington ','Lowell ',
# 'Manchester ','Westminster ','Richmond ','West Jordan ','Billings ','Clearwater ','Evansville ','West Palm Beach ','Meridian ','Cambridge ','Round Rock ','Richardson ',
# 'Palm Bay ','Fairfield ','Clovis ','College Station ','Hartford ','Lafayette','Rochester ','Independence ','Ann Arbor ','Berkeley ','Arvada ','Abilene ']

def check_if_wordpress(r):
    if "wordpress" in r.text:
        return True
    else:
        return False

def scrap_href(soup):
    for link in soup.find_all("div", {"class":"g"}):
        global i, n, next_page_url, links
        i += 1
        links = link.a["href"]
        links = links.split("/", 3)[:3]
        links[1] = "//"
        links[0:3] = [''.join(links[0:3])]
        links_list["Pos #"].append(i)
        links_list["Page #"].append(n)
        links_list["Website"].append(links[0])
        print(f"{i}: {links}")    

#Scrapping URLs
for city in cities:
    url = f"https://www.google.com/search?q={search_for}+{city}"
    response = requests.get(url, headers=headers, timeout=5)
    soup = BeautifulSoup(response.text, 'lxml')
    scrap_href(soup)
    while n < 10: #number of pages to scrap should be 10
        n += 1 
        next_page_url = soup.find("a", {"aria-label":f"Page {n}"})["href"]
        response = requests.get(f"https://google.com{next_page_url}", headers=headers)
        soup = BeautifulSoup(response.text, 'lxml')
        scrap_href(soup)

df = pd.DataFrame(links_list)
df = df[~df['Website'].isin(['https://allegro.pl', 'https://www.olx.pl', 'https://pl.wikipedia.org', 'https://www.facebook.com', 'https://maps.google.com',
'https://www.yelp.com', 'https://www.indeed.com', 'https://www.opencare.com', 'https://www.zocdoc.com'])]
df = df.drop_duplicates(subset=['Website'])
df = df.reset_index(drop=True)

now = datetime.now().strftime("%d-%m-%Y_%H-%M")
df.to_excel(rf"C:\Projekty\Coding\wp_security_report\g_scrap_.xlsx")
# Out:
# 1: ['https://www.dentalcareseattle.com']
# 2: ['https://www.seattlemet.com']
# 3: ['https://www.opencare.com']
# 4: ['https://seattlesmilesdental.com']
# 5: ['https://www.zocdoc.com']
# 6: ['https://seattlecrownhilldental.com']
# 7: ['https://www.yelp.com']
# 8: ['https://www.aestheticasmiles.com']
# 9: ['https://www.seattledentalco.com']
# 10: ['https://seattledentistry.com']
# 11: ['https://dentistdowntownseattle.com']
# 12: ['https://www.greenleafdentalseattle.com']
# 13: ['https://seattlewadentistry.com']
# 14: ['https://www.dentistsofqueenanne.com']
# 15: ['https://northseattledental.com']
# 16: ['https://www.seattledentalassociates.com']
# 17: ['https://www.flossseattle.com']
# 18: ['https://www.guyrobertsdds.com']
# 19: ['https://www.brightnow.com']
# 20: ['https://www.chriswagnerdds.com']
# 21: ['https://www.brennerdentalcare.com']
# 22: ['https://seattlesounddental.com']
# 23: ['https://qahilltop.com']
# 24: ['https://www.fidleronthetooth.com']
# 25: ['https://www.cindytsengdds.com']
# 26: ['https://www.seattlesfamilydentistry.com']
# 27: ['https://seattlesdowntowndentist.com']
# 28: ['https://www.rooseveltdental.com']
# 29: ['https://www.amatodentalgroup.com']
# 30: ['https://downtownseattledentists.com']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16812/1417276040.py in <module>
#      54         n += 1
#      55         next_page_url = soup.find("a", {"aria-label":f"Page {n}"})["href"]
# ---> 56         response = requests.get(f"https://google.com{next_page_url}", headers=headers)
#      57         soup = BeautifulSoup(response.text, 'lxml')
#      58         scrap_href(soup)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
