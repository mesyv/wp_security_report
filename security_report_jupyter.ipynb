# %%
# Objective
# This script checks for WordPress vulnerabilities
# Author: Kamil Smolag
# Start Date: 2022 August 17
# Last Modified: 2022 August 31

# --- Imports
import socket
import ssl
import requests
import json
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd



# --- Variables
headers = {
    "User-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36"
}

# --- Functions
# try and
def try_except(func, *arg):
    try:
        result = func(*arg)
        print(func.__name__, ": ", result)
        return result
    except Exception as e:
        print(e)
        return "N/a"

#check if WordPress
def check_if_wordpress(r):
    if "wordpress" in r.text:
        return True
    else:
        return False

#check WordPress version
def check_wordpress_version(r):
    soup = BeautifulSoup(r.text, 'lxml')
    generators = soup.find_all("meta", {"name":"generator"}) # Looking for <meta name="generator" content="WordPress X.X.X">
    for g in generators: # There is many <meta name="generator"...> in page
        if "WordPress" in g["content"]: 
            if len(g["content"]) < 18: # Some of the "generators" are from plugins, could include WordPress in "content"
                return g["content"].strip("WordPress ") # Taking only number of WordPress
        else:
            return "N/a"

#check SSL
def ssl_check(hostname):
    context = ssl.create_default_context()
    conn = context.wrap_socket(socket.socket(socket.AF_INET), server_hostname=hostname,)
    conn.settimeout(3.0)
    conn.connect((hostname, 443))
    ssl_info = conn.getpeercert()
    Exp_ON = datetime.strptime(ssl_info['notAfter'], r"%b %d %H:%M:%S %Y %Z")
    # Days_Remaining = Exp_ON - datetime.utcnow()
    # Days_Remaining = int((Days_Remaining.total_seconds()/3600)/24) # Converting timedelta to seconds -> hours -> days
    Exp_ON = Exp_ON.strftime('%Y-%b-%d') # Changing date format
    # print("Expires ON:", Exp_ON, "\nRemaining:", Days_Remaining)
    return Exp_ON

#check DNS
def dns_check(hostname):
    return socket.gethostbyname(hostname)

#check robots.txt
def check_robots(hostname):
    hostname = hostname + "/robots.txt"
    r = requests.get(hostname)
    if r.status_code == 200:
        return True
    else:
        return False

#check /wp-json
def check_wpjson(hostname):
    hostname = hostname + "/wp-json/"
    r = requests.get(hostname, allow_redirects=False)
    if r.status_code == 200:
        return True
    else:
        return False

#check /wp-json/wp/v2/users 
def wpjson_users_check(hostname_url):
    wpjson_links = ["/wp-json/wp/v2/users", "/wp-json/wp/v2/UsErS", "/?rest_route=/wp/v2/users",  "/wp-json/wp/v2/users/1", 
    f"/wp-json/oembed/1.0/embed?url={hostname_url}/&format=json"]
    for link in wpjson_links:
        url = hostname_url + link
        r = requests.get(url, headers=headers)
        if r.status_code == 200:
            return link
    return "N/A"

#print /wp-json/wp/v2/users 
def wpjson_users_print(url):
    r = requests.get(url, headers=headers)
    json_users = json.loads(r.text) #[1]["name"]
    users_data = {}
    for u in json_users:
        users_data[u["slug"]] = u["name"]
    return users_data

#check Security Headers
def scan_security_headers(url_headers):
    keys = ["X-XSS-Protection", "X-Content-Type-Options", "x-frame-options", "Strict-Transport-Security", "referrer-policy", "Content-Security-Policy"]
    security_headers_dict = {}
    for key in keys:
        try:
            #print(key, ": ", url_headers[key])
            if url_headers[key]:
                security_headers_dict[key] = url_headers[key]
        except KeyError:
            security_headers_dict[key] = "N/a"
            pass
    return security_headers_dict

#check XML-RPC
def check_xmlrpc(hostname):
    url = hostname + "/xmlrpc.php"
    r = requests.get(url)
    if "XML-RPC server accepts POST requests only." in r.text:
        return True
    else:
        return False

#check /wp-includes
def check_wp_includes(hostname):
    hostname = hostname + "/wp-includes"
    r = requests.get(hostname)
    if r.status_code == 200:
        return True
    else:
        return False

#check /wp-content/uploads/
def check_wp_content_uploads(hostname):
    hostname = hostname + "/wp-content/uploads/"
    r = requests.get(hostname, allow_redirects=False)
    if r.status_code == 200:
        return True
    else:
        return False

#check Theme/Plugins version
#check http://www.yoursite.com/wp-admin/maint/repair.php
# in the future

websites = []
wordpress = []
wordpress_version = []
dns_address = []
ssl_cert = []
robots = []
wp_json = []
wp_json_users_link = []
wp_json_users_list = []
security_headers = []
xmlrpc = []
wp_includes = []
wp_content = []

test_list = ["perfectweb.today", "emazzanti.net", "messagingarchitects.com"]
clientsites_list = [
    "airbrasive.com", "alvapictures.com", "bkrllc.com", "castlehotelandspa.com", "chclearningcenter.org", "filtnews.com",
    "fiberjournal.com", "fortunefootwear.com", "rocklandrealty.com", "sankaraspa.com", "visitnyack.org", "bcc.us.com", "fmbsteel.com",
    "mattoon-lee.com", "foodbanknyc.org", "ericarobert.com",
]
oursites_list = [
    "emazzanti.net", "liqui-site.com", "messagingarchitects.com", "emazzanti.ninja", "businesscontinuityvault.com", 
    "cloudtechnology365.com", "emazzantifashion.com", "emazzantijewelrygroup.com", "guarddepot.com", "retailpaytech.com", 
    "virtualfirewall.com", "egovernance.com", 
]

if __name__ == "__main__":
    for hostname in clientsites_list:
        websites.append(hostname)
        print("-----------------------------------------------------------")
        print(hostname)
        try:
            if not "http" in hostname:
                url = "https://" + hostname
                print(url)
            r = requests.get(url)
        except:
            if not "http" in hostname:
                url = "http://" + hostname
                print(url)
            r = requests.get(url, verify=False)
        print("===")
        
        wordpress.append(try_except(check_if_wordpress, r))
        wordpress_version.append(try_except(check_wordpress_version, r))
        dns_address.append(try_except(dns_check, hostname))
        ssl_cert.append(try_except(ssl_check, hostname))
        robots.append(try_except(check_robots, url))
        wp_json.append(try_except(check_wpjson, url))
        wp_json_users_link_var = try_except(wpjson_users_check, url) #saving wp_json user link to variable to use in IF
        wp_json_users_link.append(wp_json_users_link_var)
        if wp_json_users_link_var != "N/a": #If user enumeration is disabled no need to scrap the users
            wp_json_users_list.append(try_except(wpjson_users_print, url + wp_json_users_link_var))
        else:
            wp_json_users_list.append("N/a")
        security_headers.append(try_except(scan_security_headers, r.headers))
        xmlrpc.append(try_except(check_xmlrpc, url))
        wp_includes.append(try_except(check_wp_includes, url))
        wp_content.append(try_except(check_wp_content_uploads, url))
       


final_data = {
    #"Scrap date" : datetime.now().strftime("%Y-%b-%d %H-%M"),
    "Website" : websites,
    "WordPress" : wordpress,
    "WP version" : wordpress_version,
    "DNS" : dns_address,
    "SSL" : ssl_cert,
    "wp_json" : wp_json,
    "wp_json_users_link" : wp_json_users_link,
    "wp_json_users_list" : wp_json_users_list,
    "Security Headers" : security_headers,
    "Robots.txt" : robots,
    "XML-RPC" : xmlrpc,
    "wp_includes" : wp_includes,
    "wp_content" : wp_content,

    #...
}

dt = pd.DataFrame(final_data)#, index=False)
dt.to_excel(r"C:\Projekty\Coding\wp_security_report\security_report.xlsx")
print(dt)
# Out:
# -----------------------------------------------------------
# airbrasive.com
# https://airbrasive.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  None
# dns_check :  40.88.38.84
# ssl_check :  2022-Sep-25
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://airbrasive.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# alvapictures.com
# https://alvapictures.com
# http://alvapictures.com
# C:\Users\kamil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'alvapictures.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ===
# check_if_wordpress :  False
# check_wordpress_version :  None
# dns_check :  13.92.214.173
# [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)
# HTTPSConnectionPool(host='alvapictures.com', port=443): Max retries exceeded with url: /robots.txt (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')))
# check_wpjson :  False
# HTTPSConnectionPool(host='alvapictures.com', port=443): Max retries exceeded with url: /wp-json/wp/v2/users (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')))
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# HTTPSConnectionPool(host='alvapictures.com', port=443): Max retries exceeded with url: /xmlrpc.php (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')))
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# bkrllc.com
# https://bkrllc.com
# ===
# check_if_wordpress :  False
# check_wordpress_version :  None
# dns_check :  40.88.38.84
# ssl_check :  2022-Sep-25
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://bkrllc.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# castlehotelandspa.com
# https://castlehotelandspa.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  40.88.38.84
# ssl_check :  2022-Dec-27
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://castlehotelandspa.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# chclearningcenter.org
# https://chclearningcenter.org
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  40.88.38.84
# ssl_check :  2022-Sep-28
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/wp/v2/users
# wpjson_users_print :  {'emazzanti': 'emazzanti', 'jgentz': 'Jan Gentz', 'ngodson': 'Nancy Godson'}
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# filtnews.com
# https://filtnews.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  13.92.214.173
# ssl_check :  2022-Nov-15
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/wp/v2/users
# wpjson_users_print :  {'adrian-wilson': 'Adrian Wilson', 'bperlmutter': 'Barry A. Perlmutter', 'bob-mcilvaine': 'Bob McIlvaine', 'bkalil': 'Brad Kalil', 'drm': 'Bradley Moakler B.S. ChE, Benjamin Dietiker B.S.E.M., Klaus Julkowski, Ph.D., ChE', 'mycelx': 'Brian Deurloo and Haluk Alper', 'camfilpower': 'Camfil Power Systems', 'cplotz': 'Chris Plotz', 'cscoble': 'Clint Scoble', 'dmorosky': 'Dan Morosky'}
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# fiberjournal.com
# https://fiberjournal.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  None
# dns_check :  64.71.128.227
# ssl_check :  2023-Sep-28
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://fiberjournal.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  False
# check_wp_content_uploads :  False
# -----------------------------------------------------------
# fortunefootwear.com
# https://fortunefootwear.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  None
# dns_check :  13.92.214.173
# ssl_check :  2022-Oct-06
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://fortunefootwear.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# rocklandrealty.com
# https://rocklandrealty.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  None
# dns_check :  40.88.38.84
# ssl_check :  2022-Sep-18
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://rocklandrealty.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# sankaraspa.com
# https://sankaraspa.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  40.88.38.84
# ssl_check :  2022-Sep-22
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://sankaraspa.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# visitnyack.org
# https://visitnyack.org
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  40.88.38.84
# ssl_check :  2022-Oct-13
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/wp/v2/users
# wpjson_users_print :  {'cscimone': 'Caroline Scimone', 'nllerandi': 'Nicholas Llerandi', 'swilmink': 'Susan Wilmink', 'visit-nyack': 'Visit Nyack'}
# scan_security_headers :  {'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'x-frame-options': 'ALLOWALL', 'Strict-Transport-Security': 'max-age=63072000; includeSubDomains; preload', 'referrer-policy': 'strict-origin-when-cross-origin', 'Content-Security-Policy': 'report-uri https://visitnyack.org'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# bcc.us.com
# https://bcc.us.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  None
# dns_check :  188.114.97.13
# ssl_check :  2022-Oct-09
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://bcc.us.com/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  False
# check_wp_content_uploads :  False
# -----------------------------------------------------------
# fmbsteel.com
# https://fmbsteel.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  N/a
# dns_check :  13.92.214.173
# ssl_check :  2022-Oct-15
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/wp/v2/users
# wpjson_users_print :  {'alec': 'alec', 'savioradmin': 'savioradmin'}
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# -----------------------------------------------------------
# mattoon-lee.com
# https://mattoon-lee.com
# ===
# check_if_wordpress :  False
# check_wordpress_version :  None
# dns_check :  40.88.38.84
# ssl_check :  2022-Oct-13
# check_robots :  False
# check_wpjson :  False
# wpjson_users_check :  /?rest_route=/wp/v2/users
# Expecting value: line 1 column 1 (char 0)
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  False
# check_wp_content_uploads :  False
# -----------------------------------------------------------
# foodbanknyc.org
# https://foodbanknyc.org
# ===
# check_if_wordpress :  False
# check_wordpress_version :  None
# dns_check :  3.231.0.221
# ssl_check :  2022-Sep-23
# check_robots :  False
# check_wpjson :  False
# wpjson_users_check :  /wp-json/oembed/1.0/embed?url=https://foodbanknyc.org/&format=json
# string indices must be integers
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  False
# check_wp_includes :  False
# check_wp_content_uploads :  False
# -----------------------------------------------------------
# ericarobert.com
# https://ericarobert.com
# ===
# check_if_wordpress :  True
# check_wordpress_version :  6.0.2
# dns_check :  188.114.97.13
# ssl_check :  2022-Nov-24
# check_robots :  True
# check_wpjson :  True
# wpjson_users_check :  /wp-json/wp/v2/users
# wpjson_users_print :  {'ggedik': 'ggedik'}
# scan_security_headers :  {'X-XSS-Protection': 'N/a', 'X-Content-Type-Options': 'N/a', 'x-frame-options': 'N/a', 'Strict-Transport-Security': 'N/a', 'referrer-policy': 'N/a', 'Content-Security-Policy': 'N/a'}
# check_xmlrpc :  True
# check_wp_includes :  True
# check_wp_content_uploads :  True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16100/1312425379.py in <module>
#     231 }
#     232
# --> 233 dt = pd.DataFrame(final_data, index=False)
#     234 dt.to_excel(r"C:\Projekty\Coding\wp_security_report\security_report.xlsx")
#     235 print(dt)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     119             index = _extract_index(arrays)
#     120         else:
# --> 121             index = ensure_index(index)
#     122
#     123         # don't force copy because getting jammed in an ndarray anyway
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    6335     else:
#    6336
# -> 6337         return Index(index_like, copy=copy)
#    6338
#    6339
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     472
#     473         elif is_scalar(data):
# --> 474             raise cls._scalar_data_error(data)
#     475         elif hasattr(data, "__array__"):
#     476             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, False was passed
